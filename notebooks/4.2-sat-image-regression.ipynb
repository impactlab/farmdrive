# %%
# %matplotlib inline

import os

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

DATA_ROOT = os.path.join(os.getcwd(), os.pardir, 'data')

# %%
# Relevant data sources
# !tree {DATA_ROOT}/regression
# Out:
# /Users/bull/farmdrive/notebooks/../data/regression
# ├── all_ward_data_55wards.csv
# ├── farmer_loan_results.csv
# ├── farmer_wards.csv
# └── march17_ward_data_modis.csv
#
# 0 directories, 4 files

# %% [markdown]
# # Load the data about the farmers
#
# Data about the loans and about the ward locations of the farmers were provided separately. Load those datasets and join them on the farmer index.

# %%
farmer_loans = pd.read_csv(os.path.join(DATA_ROOT,
                           'regression',
                           'farmer_loan_results.csv'))

farmer_loans.set_index('fmr_id', inplace=True)

print(farmer_loans.shape)
farmer_loans.head()
# Out:
# (369, 30)
#         loan_id  loanstatus_id  fdscoreV0_5  rollstatus   loan_date  \
# fmr_id
# 392         870              3          NaN           0  1490169718
# 1445        871              3          NaN           0  1490175823
# 2094        872              3          NaN           0  1490229958
# 2276        873              3          NaN           0  1490445134
# 2266        874              4          NaN           1  1490598771
#
#         loan_amnt_requested  loan_dateout  loan_issued  loan_principal  \
# fmr_id
# 392                      20             0           21              20
# 1445                   4000             0         4200            4000
# 2094                    500             0          525             500
# 2276                   3000             0         3150            3000
# 2266                   4000             0         4200            4000
#
#         loan_interest  cur_id  loan_fee  loan_rate  loan_period  \
# fmr_id
# 392                 1       1         0          0           30
# 1445              200       1         0          0           30
# 2094               25       1         0          0           30
# 2276              150       1         0          0           30
# 2266              200       1         0          0           30
#
#         loan_graceperiod  loan_repaystart     loan_purpose  loanprod_id  \
# fmr_id
# 392                    0       1492732800  Short Term Loan            2
# 1445                   0       1492732800  Short Term Loan            2
# 2094                   0       1492819200  Short Term Loan            2
# 2276                   0       1493164800  Short Term Loan            2
# 2266                   0       1493164800  Short Term Loan            2
#
#         loan_created  mfi_id  ltrans_id  loan_id.1  ltrans_amountdue  \
# fmr_id
# 392       1490169718       1       1274        870                21
# 1445      1490175823       1       1275        871              4200
# 2094      1490229958       1       1276        872               525
# 2276      1490445134       1       1280        873              3150
# 2266      1490598771       1       1281        874              4200
#
#         ltrans_due  ltrans_amountpaid   ltrans_date  ltrans_repaytype  \
# fmr_id
# 392     1492732800                 21  1.490684e+09                 1
# 1445    1492732800               4200  1.492435e+09                 1
# 2094    1492819200                525  1.492532e+09                 1
# 2276    1493164800               3150  1.490881e+09                 1
# 2266    1493164800                  0           NaN                 1
#
#        ltrans_receipt  ltrans_created  user_id
# fmr_id
# 392              S_08      1490169746      100
# 1445             S_15      1490175981      100
# 2094             S_16      1490229973      100
# 2276            S_010      1490616175      100
# 2266              NaN      1490616512      100

# %%
farmer_wards = pd.read_csv(os.path.join(DATA_ROOT,
                                        'regression',
                                        'farmer_wards.csv'),
                           index_col=0)

farmer_wards.set_index('fmr_id', inplace=True)
farmer_wards.drop('loanid', axis=1, inplace=True)
farmer_wards.dropna(inplace=True)

farmer_wards = farmer_wards.reset_index().drop_duplicates().set_index('fmr_id')

print(farmer_wards.shape)
farmer_wards.head()
# Out:
# (245, 1)
#                    ward
# fmr_id
# 2094              BURAT
# 2276      KARATINA TOWN
# 2412             SHEYWE
# 2380       MALINDI TOWN
# 1329    DANDORA AREA IV

# %%
all_farmer_data = farmer_loans.join(farmer_wards, how='left')

all_farmer_data.columns.tolist()

all_farmer_data.shape
# Out:
# (369, 31)

# %%
all_farmer_data.head()
# Out:
#         loan_id  loanstatus_id  fdscoreV0_5  rollstatus   loan_date  \
# fmr_id
# 98          901              3          NaN           0  1492260594
# 98         1182              4          NaN           1  1500030248
# 98         1182              4          NaN           1  1500030248
# 174        1076              4          NaN           1  1498834578
# 174        1076              4          NaN           1  1498834578
#
#         loan_amnt_requested  loan_dateout  loan_issued  loan_principal  \
# fmr_id
# 98                     4000             0         4200            4000
# 98                     4500             0         4725            4500
# 98                     4500             0         4725            4500
# 174                    4000             0         4200            4000
# 174                    4000             0         4200            4000
#
#         loan_interest  cur_id  loan_fee  loan_rate  loan_period  \
# fmr_id
# 98                200       1         0          0           30
# 98                225       1         0          0           30
# 98                225       1         0          0           30
# 174               200       1         0          0           30
# 174               200       1         0          0           30
#
#         loan_graceperiod  loan_repaystart     loan_purpose  loanprod_id  \
# fmr_id
# 98                     0       1494806400  Short Term Loan            2
# 98                     0       1502582400  Short Term Loan            2
# 98                     0       1502582400  Short Term Loan            2
# 174                    0       1501372800  Short Term Loan            2
# 174                    0       1501372800  Short Term Loan            2
#
#         loan_created  mfi_id  ltrans_id  loan_id.1  ltrans_amountdue  \
# fmr_id
# 98        1492260594       1       1292        901              4200
# 98        1500030248       1       1474       1182              4725
# 98        1500030248       1       1625       1182               236
# 174       1498834578       1       1425       1076              4200
# 174       1498834578       1       1564       1076               210
#
#         ltrans_due  ltrans_amountpaid   ltrans_date  ltrans_repaytype  \
# fmr_id
# 98      1494806400               4200  1.494819e+09                 1
# 98      1502582400                  0           NaN                 1
# 98      1502773086                  0           NaN                 1
# 174     1501372800                  0           NaN                 1
# 174     1501563487                  0           NaN                 1
#
#        ltrans_receipt  ltrans_created  user_id         ward
# fmr_id
# 98               S_53      1492260647      100  CENTRAL GEM
# 98                NaN      1500030325      100  CENTRAL GEM
# 98                NaN      1502773085      100  CENTRAL GEM
# 174               NaN      1498834663      100          NaN
# 174               NaN      1501563486      100          NaN

# %% [markdown]
# # Load the satellite data
#
# Load data from the satellite imagery:
#
#  - `planet`: normalized indices calculated from RapidEye imagery for Fall of 2016
#  - `modis`: indices from MODIS data for March of 2017

# %%
planet = pd.read_csv(os.path.join(DATA_ROOT,
                                  'regression',
                                  'all_ward_data_55wards.csv'))

planet.columns = ['clean_ward'] + planet.columns[1:].tolist()
planet.head()
# Out:
#         clean_ward  npcri_mean  npcri_pct_likely  npcri_std  re_ndvi_mean  \
# 0            BURAT   -0.019640          0.000680   0.106702      0.029443
# 1    KARATINA-TOWN         NaN               NaN        NaN           NaN
# 2           SHEYWE         NaN               NaN        NaN           NaN
# 3  DANDORA-AREA-IV         NaN               NaN        NaN           NaN
# 4         KABIEMIT   -0.186776          0.000088   0.090035      0.243724
#
#    re_ndvi_pct_likely  re_ndvi_std  re_ndwi_mean  re_ndwi_pct_likely  \
# 0            0.033688     0.080855      0.029676            0.005576
# 1                 NaN          NaN           NaN                 NaN
# 2                 NaN          NaN           NaN                 NaN
# 3                 NaN          NaN           NaN                 NaN
# 4            0.637099     0.465345     -0.999495            0.000043
#
#    re_ndwi_std
# 0     0.062745
# 1          NaN
# 2          NaN
# 3          NaN
# 4     0.013199

# %%
modis = pd.read_csv(os.path.join(DATA_ROOT,
                                 'regression',
                                 'march17_ward_data_modis.csv'),
                     index_col=0)
modis.head()
# Out:
#                                lai       fpar         ndvi          evi  \
# name
# BARINGO.BARTABWA          6.095819  27.085366  3454.406497  1698.579017
# BARINGO.BARWESSA          5.765996  25.060329  3038.832649  1651.995440
# BARINGO.CHURO/AMAYA       5.755814  24.443798  3146.186712  1498.047042
# BARINGO.EMINING           9.243478  24.826087  2729.090949  1307.118933
# BARINGO.EWALEL/CHAPCHAP  11.142857  39.780952  4528.734767  2345.976105
#
#                                  sr1          sr2         sr3          sr4  \
# name
# BARINGO.BARTABWA         1090.278753  2219.430641  476.981124   853.862160
# BARINGO.BARWESSA         1405.999544  2594.552212  569.533972  1047.590971
# BARINGO.CHURO/AMAYA      1090.379728  2097.806014  450.841416   824.061106
# BARINGO.EMINING          1208.469174  2103.227372  467.473983   851.918233
# BARINGO.EWALEL/CHAPCHAP   954.836320  2523.702509  426.219833   828.217443
#
#                                  sr5          sr6          sr7
# name
# BARINGO.BARTABWA         2956.929324  2869.609306  2169.833626
# BARINGO.BARWESSA         3352.410853  3362.103055  2799.213862
# BARINGO.CHURO/AMAYA      2874.952473  2875.301164  2209.502910
# BARINGO.EMINING          2739.296021  2739.215129  2282.237676
# BARINGO.EWALEL/CHAPCHAP  3081.749104  2602.876941  1727.026284

# %%
modis['clean_ward'] = (modis.index
                      .to_series()
                      .str
                      .split('.')
                      .apply(
            lambda x: x[1].replace('/', '-').replace(' ', '-')))

modis.set_index('clean_ward', inplace=True)

# %% [markdown]
# ## Check ward overlap
#
# Make sure that the wards have been updated so that they match across datasets.

# %%
all_farmer_data['clean_ward'] = (all_farmer_data.ward
                                                .apply(
              lambda x: str(x).replace('/', '-').replace(' ', '-')))

# %%
# planet data is missing 6 of the wards we see in the farmer data
np.setdiff1d(all_farmer_data.clean_ward,
             planet.index)
# Out:
# array(['KARUNA-MEIBEKI', 'KINANGO', 'MALINDI-TOWN', 'NGONG',
#        'NORTH-KINANGOP', 'SOY', 'nan'], dtype=object)

# %%
# modis has all of the wards that we see in the farmer data22
np.setdiff1d(all_farmer_data.clean_ward,
             modis.clean_ward)
# Out:
# array(['nan'], dtype=object)

# %% [markdown]
# # Features

# %% [markdown]
# ## Build Loan features
#
# Drop features that:
#  - only have a single value
#  - are just unique identifiers rather than data about the loan
#  - drop features that we wouldn't have ahead of time (i.e., when we decide to make the loan)
#
# Only look at non-rollover loans, since (presumably those are the ones we care about).

# %%
# number of unique values in each column per loan
all_farmer_data.groupby('loan_id').nunique().nunique()
# Out:
# loan_id                1
# loanstatus_id          1
# fdscoreV0_5            2
# rollstatus             1
# loan_date              1
# loan_amnt_requested    1
# loan_dateout           1
# loan_issued            1
# loan_principal         1
# loan_interest          1
# cur_id                 1
# loan_fee               1
# loan_rate              1
# loan_period            1
# loan_graceperiod       1
# loan_repaystart        1
# loan_purpose           1
# loanprod_id            1
# loan_created           1
# mfi_id                 1
# ltrans_id              2
# loan_id.1              1
# ltrans_amountdue       2
# ltrans_due             2
# ltrans_amountpaid      2
# ltrans_date            3
# ltrans_repaytype       1
# ltrans_receipt         3
# ltrans_created         2
# user_id                1
# ward                   2
# clean_ward             1
# dtype: int64

# %%
farmer_features = all_farmer_data.reset_index().groupby('loan_id').agg({
    'loanstatus_id': 'first',  # these are all the same, see check above
    'rollstatus': 'first',
    'loan_date': 'first',
    'loan_amnt_requested': 'first',
    'loan_issued': 'first',
    'loan_principal': 'first',
    'loan_interest': 'first',
    'loan_repaystart': 'first',
    'loan_created': 'first',
    'clean_ward': 'first'
})

# %%
print(farmer_features.shape)
farmer_features = farmer_features[farmer_features.clean_ward != 'nan']
print(farmer_features.shape)
# Out:
# (235, 10)
# (226, 10)

# %%
# 3 is repaid, 4 is abandoned
target_loan_repayment = (farmer_features.loanstatus_id == 3.0).astype(int)

farmer_features = farmer_features.drop('loanstatus_id', axis=1)

# %%
farmer_features.dtypes
# Out:
# rollstatus              int64
# loan_date               int64
# loan_amnt_requested     int64
# loan_issued             int64
# loan_principal          int64
# loan_interest           int64
# loan_repaystart         int64
# loan_created            int64
# clean_ward             object
# dtype: object

# %% [markdown]
# # Modeling

# %%
from sklearn.preprocessing import StandardScaler

# drop co-linear vars
X = farmer_features.drop(['loan_interest', 'loan_principal', 'loan_repaystart', 'clean_ward'],
                         axis=1)

ss = StandardScaler()
X_vals = ss.fit_transform(X)


X_vals = pd.DataFrame(data=X_vals, columns=X.columns, index=X.index)

# %% [markdown]
# ## Model Just Loan Features

# %%
import statsmodels.formula.api as sm

model = sm.Logit(target_loan_repayment, X_vals)

result = model.fit_regularized(full_output=True)
result.summary()
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.26222274554580444
#             Iterations: 17
#             Function evaluations: 17
#             Gradient evaluations: 17
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          loanstatus_id   No. Observations:                  226
# Model:                          Logit   Df Residuals:                      221
# Method:                           MLE   Df Model:                            4
# Date:                Sat, 30 Sep 2017   Pseudo R-squ.:                  0.6212
# Time:                        15:51:34   Log-Likelihood:                -59.262
# converged:                       True   LL-Null:                       -156.43
#                                         LLR p-value:                 6.203e-41
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# rollstatus             -2.6071      0.278     -9.375      0.000      -3.152      -2.062
# loan_date              -0.0183   2.51e+07  -7.27e-10      1.000   -4.93e+07    4.93e+07
# loan_amnt_requested     0.0863   1834.103   4.71e-05      1.000   -3594.690    3594.862
# loan_issued             0.0862   1834.108    4.7e-05      1.000   -3594.700    3594.873
# loan_created           -0.0183   2.51e+07  -7.27e-10      1.000   -4.93e+07    4.93e+07
# =======================================================================================
# """

# %% [markdown]
# ## Model Loan + MODIS Features

# %%
# drop co-linear vars
X = farmer_features.drop(['loan_interest', 'loan_principal', 'loan_repaystart'],
                         axis=1)

print(X.shape)
X = X.merge(modis.reset_index(), on='clean_ward')
print(X.shape)

X.drop('clean_ward', inplace=True, axis=1)

ss = StandardScaler()
X_vals = ss.fit_transform(X)


X_vals = pd.DataFrame(data=X_vals, columns=X.columns, index=target_loan_repayment.index)
# Out:
# (226, 6)
# (226, 17)

# %%
model = sm.Logit(target_loan_repayment, X_vals)

result = model.fit(method='bfgs', full_output=True)
result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.658902
#          Iterations: 35
#          Function evaluations: 36
#          Gradient evaluations: 36
# /Users/bull/anaconda3/envs/farmdrive/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          loanstatus_id   No. Observations:                  226
# Model:                          Logit   Df Residuals:                      211
# Method:                           MLE   Df Model:                           14
# Date:                Sat, 30 Sep 2017   Pseudo R-squ.:                 0.04806
# Time:                        18:07:44   Log-Likelihood:                -148.91
# converged:                      False   LL-Null:                       -156.43
#                                         LLR p-value:                    0.3757
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# rollstatus             -0.0629      0.147     -0.429      0.668      -0.350       0.224
# loan_date              -0.1484   8.86e+06  -1.67e-08      1.000   -1.74e+07    1.74e+07
# loan_amnt_requested    -0.1307   1033.421     -0.000      1.000   -2025.599    2025.337
# loan_issued            -0.1317   1033.423     -0.000      1.000   -2025.603    2025.340
# loan_created           -0.1484   8.86e+06  -1.67e-08      1.000   -1.74e+07    1.74e+07
# lai                    -0.0789      2.831     -0.028      0.978      -5.628       5.470
# fpar                    0.2014      2.801      0.072      0.943      -5.289       5.692
# ndvi                    1.1713      1.140      1.028      0.304      -1.062       3.405
# evi                     0.3149      1.183      0.266      0.790      -2.004       2.634
# sr1                     0.3277      1.029      0.318      0.750      -1.690       2.345
# sr2                    -1.5632      1.799     -0.869      0.385      -5.089       1.963
# sr3                    -0.1858      1.071     -0.173      0.862      -2.286       1.914
# sr4                     0.2957      1.167      0.253      0.800      -1.992       2.583
# sr5                     0.6162      2.478      0.249      0.804      -4.241       5.473
# sr6                    -0.0292      2.296     -0.013      0.990      -4.530       4.472
# sr7                     0.3055      1.449      0.211      0.833      -2.534       3.145
# =======================================================================================
# """

# %% [markdown]
# ## Model Loan + planet Features

# %%
# drop co-linear vars
X = farmer_features.drop(['loan_interest', 'loan_principal', 'loan_repaystart'],
                         axis=1)


print(X.shape)
X = X.merge(planet, how='left', on='clean_ward')
print(X.shape)

X.fillna(-10, inplace=True)

X.drop('clean_ward', inplace=True, axis=1)

ss = StandardScaler()
X_vals = ss.fit_transform(X)

X_vals = pd.DataFrame(data=X_vals, columns=X.columns, index=target_loan_repayment.index)
# Out:
# (226, 6)
# (226, 15)

# %%
model = sm.Logit(target_loan_repayment, X_vals)

result = model.fit(method='newton', full_output=True)
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.257750
#          Iterations 20
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          loanstatus_id   No. Observations:                  226
# Model:                          Logit   Df Residuals:                      213
# Method:                           MLE   Df Model:                           12
# Date:                Sat, 30 Sep 2017   Pseudo R-squ.:                  0.6276
# Time:                        18:33:06   Log-Likelihood:                -58.252
# converged:                       True   LL-Null:                       -156.43
#                                         LLR p-value:                 1.841e-35
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# rollstatus             -2.6322      0.292     -9.001      0.000      -3.205      -2.059
# loan_date              -0.0184   2.55e+07  -7.23e-10      1.000   -4.99e+07    4.99e+07
# loan_amnt_requested  1199.4213   2062.653      0.581      0.561   -2843.304    5242.146
# loan_issued         -1199.2772   2062.651     -0.581      0.561   -5241.999    2843.445
# loan_created           -0.0184   2.55e+07  -7.23e-10      1.000   -4.99e+07    4.99e+07
# npcri_mean             -7.8063     32.328     -0.241      0.809     -71.168      55.555
# npcri_pct_likely       -2.8676     65.969     -0.043      0.965    -132.165     126.430
# npcri_std             -92.3561    105.633     -0.874      0.382    -299.392     114.680
# re_ndvi_mean           -5.0637     20.834     -0.243      0.808     -45.898      35.771
# re_ndvi_pct_likely     -1.1406     17.066     -0.067      0.947     -34.589      32.308
# re_ndvi_std             4.5964     15.331      0.300      0.764     -25.452      34.645
# re_ndwi_mean            0.4538     12.402      0.037      0.971     -23.853      24.761
# re_ndwi_pct_likely     -6.0927     23.474     -0.260      0.795     -52.101      39.916
# re_ndwi_std           110.2699    110.585      0.997      0.319    -106.473     327.013
# =======================================================================================
# """

# %% [markdown]
# ## Model Loan + planet + MODIS Features

# %%
# drop co-linear vars
X = farmer_features.drop(['loan_interest', 'loan_principal', 'loan_repaystart'],
                         axis=1)


print(X.shape)
X = X.merge(planet, how='left', on='clean_ward')
X = X.merge(modis.reset_index(), on='clean_ward')
print(X.shape)

X.fillna(-10, inplace=True)

X.drop('clean_ward', inplace=True, axis=1)

ss = StandardScaler()
X_vals = ss.fit_transform(X)

X_vals = pd.DataFrame(data=X_vals, columns=X.columns, index=target_loan_repayment.index)
# Out:
# (226, 6)
# (226, 26)

# %%
model = sm.Logit(target_loan_repayment, X_vals)

result = model.fit(method='newton', full_output=True)
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.638164
#          Iterations 10
# /Users/bull/anaconda3/envs/farmdrive/lib/python3.6/site-packages/statsmodels/base/model.py:1029: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_params()))
# /Users/bull/anaconda3/envs/farmdrive/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/bull/anaconda3/envs/farmdrive/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/bull/anaconda3/envs/farmdrive/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          loanstatus_id   No. Observations:                  226
# Model:                          Logit   Df Residuals:                      202
# Method:                           MLE   Df Model:                           23
# Date:                Sat, 30 Sep 2017   Pseudo R-squ.:                 0.07802
# Time:                        18:34:10   Log-Likelihood:                -144.23
# converged:                       True   LL-Null:                       -156.43
#                                         LLR p-value:                    0.3814
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# rollstatus             -0.0247      0.153     -0.161      0.872      -0.324       0.275
# loan_date              -0.1568        nan        nan        nan         nan         nan
# loan_amnt_requested   346.6283        nan        nan        nan         nan         nan
# loan_issued          -346.8583        nan        nan        nan         nan         nan
# loan_created           -0.1568        nan        nan        nan         nan         nan
# npcri_mean            -26.5289     32.713     -0.811      0.417     -90.645      37.587
# npcri_pct_likely       40.0069     67.940      0.589      0.556     -93.152     173.166
# npcri_std              15.9260     86.092      0.185      0.853    -152.812     184.664
# re_ndvi_mean            0.2767     15.467      0.018      0.986     -30.037      30.591
# re_ndvi_pct_likely    -11.1908     12.589     -0.889      0.374     -35.864      13.482
# re_ndvi_std            10.3777     10.157      1.022      0.307      -9.529      30.285
# re_ndwi_mean            5.9651      7.132      0.836      0.403      -8.014      19.944
# re_ndwi_pct_likely     -5.7773     20.229     -0.286      0.775     -45.425      33.871
# re_ndwi_std           -28.7587     83.123     -0.346      0.729    -191.677     134.159
# lai                    -1.7338      3.198     -0.542      0.588      -8.003       4.535
# fpar                    1.8457      3.185      0.579      0.562      -4.398       8.089
# ndvi                    0.9623      1.780      0.541      0.589      -2.526       4.450
# evi                     1.0473      1.427      0.734      0.463      -1.750       3.845
# sr1                     1.0789      1.278      0.844      0.398      -1.426       3.583
# sr2                    -2.7599      1.927     -1.432      0.152      -6.538       1.018
# sr3                    -0.2512      1.166     -0.215      0.829      -2.537       2.034
# sr4                     0.3153      1.412      0.223      0.823      -2.453       3.083
# sr5                     2.5986      2.663      0.976      0.329      -2.620       7.817
# sr6                    -2.1103      2.428     -0.869      0.385      -6.870       2.649
# sr7                     1.2749      1.599      0.797      0.425      -1.859       4.409
# =======================================================================================
# """
